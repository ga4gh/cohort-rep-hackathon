# %% [markdown]
# ## Using a local GA4GH Data Connect server
# This notebook was run against a DC service running against a local trino server

# %%
from fasp.search import DataConnectClient
cl = DataConnectClient('http://localhost:8089/')
#cl.listTables(verbose=True)

# %% [markdown]
# This lists the schema for one of the dbGaP asthma studies.

# %%
cl.listTableInfo('bigquery.dbgap_synth.TOPMed_WGS_CAMP_Subject_Phenotypes', verbose=True)
# Out:
# _Schema for tablebigquery.dbgap_synth.TOPMed_WGS_CAMP_Subject_Phenotypes_
# {
#    "name": "bigquery.dbgap_synth.TOPMed_WGS_CAMP_Subject_Phenotypes",
#    "data_model": {
#       "description": "This subject phenotypes data table includes subject's asthma status, gender, age, race, height, weight, BMI, and smoking status (n=3 variables; ever, current, and former).",
#       "$id": "dbgap:pht009836.v2",
#       "properties": {
#          "gender": {
#             "$id": "dbgap:phv00426560.v2",
#             "description": "Gender of participant",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "Male"
#                },
#                {
#                   "const": "2",
#                   "title": "Female"
#                }
#             ]
#          },
#          "race": {
#             "$id": "dbgap:phv00426562.v2",
#             "description": "Race of participant",
#             "type": "string"
#          },
#          "SUBJECT_ID": {
#             "$id": "dbgap:phv00426559.v2",
#             "description": "De-identified Subject ID",
#             "type": "string"
#          },
#          "weight": {
#             "$id": "dbgap:phv00426565.v2",
#             "description": "Weight in kg",
#             "type": "decimal",
#             "$unit": "kg"
#          },
#          "asthma": {
#             "$id": "dbgap:phv00493726.v1",
#             "description": "Case control status of the subject for asthma",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "Unknown"
#                },
#                {
#                   "const": "1",
#                   "title": "Asthma case (proband)"
#                },
#                {
#                   "const": "2",
#                   "title": "Control"
#                }
#             ]
#          },
#          "current_smoker": {
#             "$id": "dbgap:phv00426568.v2",
#             "description": "Current smoking status",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "No"
#                },
#                {
#                   "const": "0",
#                   "title": "Unknown"
#                },
#                {
#                   "const": "2",
#                   "title": "Yes"
#                }
#             ]
#          },
#          "age": {
#             "$id": "dbgap:phv00426561.v2",
#             "description": "Age (for children) at randomization",
#             "type": "decimal",
#             "$unit": "years"
#          },
#          "former_smoker": {
#             "$id": "dbgap:phv00426569.v2",
#             "description": "Former smoking status",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "No"
#                },
#                {
#                   "const": "0",
#                   "title": "Unknown"
#                },
#                {
#                   "const": "2",
#                   "title": "Yes"
#                }
#             ]
#          },
#          "height": {
#             "$id": "dbgap:phv00426564.v2",
#             "description": "Height  in cm",
#             "type": "decimal",
#             "$unit": "cm"
#          },
#          "bmi": {
#             "$id": "dbgap:phv00426566.v2",
#             "description": "BMI",
#             "type": "decimal"
#          },
#          "ever_smoker": {
#             "$id": "dbgap:phv00426567.v2",
#             "description": "Ever smoked",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "No"
#                },
#                {
#                   "const": "0",
#                   "title": "Unknown"
#                },
#                {
#                   "const": "2",
#                   "title": "Yes"
#                }
#             ]
#          }
#       }
#    }
# }

# %% [markdown]
# Based on the above we can construct a query to answer a question we might be interested in.
# This summarizes the cohort according to smoking status.

# %%
query1 = '''SELECT current_smoker, ever_smoker, count(*) n
FROM bigquery.dbgap_synth.TOPMed_WGS_CAMP_Subject_Phenotypes
group by current_smoker, ever_smoker
'''

res = cl.runQuery(query1, returnType='dataframe')
res
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
# ____Page6_______________
# ____Page7_______________
# ____Page8_______________
# ____Page9_______________
#    current_smoker  ever_smoker    n
# 0               2            1   23
# 1               1            1  135
# 2               1            2   37
# 3               1            0    3
# 4               2            2    2

# %% [markdown]
# #### todo
# show how the schema lets us decode those cryptic values

# %% [markdown]
# ### Important point
# A data user gets significant value out of the machine readable data dictionary.

# %% [markdown]
# ### Another asthma dataset - WGS BAGS
# See the dataset listing to learn this is the Barbados Asthma study

# %%
cl.listTableInfo('bigquery.dbgap_synth.TOPMed_WGS_BAGS_Subject_Phenotypes', verbose=True)
# Out:
# _Schema for tablebigquery.dbgap_synth.TOPMed_WGS_BAGS_Subject_Phenotypes_
# {
#    "name": "bigquery.dbgap_synth.TOPMed_WGS_BAGS_Subject_Phenotypes",
#    "data_model": {
#       "description": "This subject phenotype table includes age, sex, and affection status for asthma. Additional variables have been added: smoking status (n=9 variables; includes mother and father smoking status), asthma age of onset, allergic rhinitis, weight, height, IgE measurements (n=3 variables), phadiatop measurements, spirometry measurements (n=3 variables), bronchodilator pills/inhalers/nebulizer (n=6 variables), steroid pills/inhalers (n=4 variables), and cromolyn inhalers (n=2 variables).",
#       "$id": "dbgap:pht005905.v3",
#       "properties": {
#          "AGE_START_SMOKING": {
#             "$id": "dbgap:phv00375340.v1",
#             "description": "Answer to \"At what age did you start smoking?\"",
#             "type": "integer, encoded value",
#             "$unit": "years",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "STEROID_PILLS": {
#             "$id": "dbgap:phv00375324.v1",
#             "description": "Steroid/prednisone pills (current use according to health questionnaire)",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "SEX": {
#             "$id": "dbgap:phv00273212.v2",
#             "description": "Sex of participant",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "Male"
#                },
#                {
#                   "const": "2",
#                   "title": "Female"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "BRONCHODILATOR_INHALERS": {
#             "$id": "dbgap:phv00375326.v1",
#             "description": "Bronchodilator inhalers (current use according to health questionnaire)",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "FEV1_PREBD": {
#             "$id": "dbgap:phv00375334.v1",
#             "description": "FEV1 = Forced Expiratory Volume 1 (pre-bronchodilator)",
#             "type": "decimal, encoded value",
#             "$unit": "liters/second",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "EVER_SMOKED_PIPE": {
#             "$id": "dbgap:phv00375345.v1",
#             "description": "Answer to \"Have you ever smoked a pipe?\"",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes ever"
#                },
#                {
#                   "const": "2",
#                   "title": "Yes currently"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "STEROID_INHALERS_RELIEF": {
#             "$id": "dbgap:phv00375329.v1",
#             "description": "Relief from steroid inhalers",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "LOG10_IGE_NG_ML": {
#             "$id": "dbgap:phv00375316.v2",
#             "description": "Log10 (Total serum IgE in ng/ml)",
#             "type": "decimal, encoded value",
#             "$unit": "ng/ml",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "BRONCHODILATOR_NEBULIZER_RELIEF": {
#             "$id": "dbgap:phv00375333.v1",
#             "description": "Relief from bronchodilator by nebulizer",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "AGE_IGE": {
#             "$id": "dbgap:phv00375318.v1",
#             "description": "Age of subject when sample used for total serum IgE measurement was collected",
#             "type": "integer, encoded value",
#             "$unit": "years",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "AGE_ONSET_ASTHMA": {
#             "$id": "dbgap:phv00375320.v1",
#             "description": "Age of asthma onset",
#             "type": "integer, encoded value",
#             "$unit": "years",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "SUBJECT_ID": {
#             "$id": "dbgap:phv00273210.v2",
#             "description": "De-identified Subject ID",
#             "type": "string"
#          },
#          "STEROID_PILLS_RELIEF": {
#             "$id": "dbgap:phv00375325.v1",
#             "description": "Relief from steroid/prednisone pills",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "CURRENT_SMOKING": {
#             "$id": "dbgap:phv00375341.v1",
#             "description": "Answer to \"Are you smoking now?\"",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "AGE_STOPPED_SMOKING": {
#             "$id": "dbgap:phv00375342.v1",
#             "description": "Answer to \"At what age did you stop smoking?\"",
#             "type": "integer, encoded value",
#             "$unit": "years",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "AGE": {
#             "$id": "dbgap:phv00273211.v2",
#             "description": "Subject age at health questionnaire administration and lung function measurement",
#             "type": "integer, encoded value",
#             "$unit": "years",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "HEIGHT_CM": {
#             "$id": "dbgap:phv00375338.v2",
#             "description": "Subject height in cm",
#             "type": "decimal, encoded value",
#             "$unit": "cm",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "IGE_BATCH": {
#             "$id": "dbgap:phv00375317.v1",
#             "description": "Batch in which total serum IgE and phadiatop measurements were run",
#             "type": "string, encoded value",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                },
#                {
#                   "title": "STRINGS"
#                }
#             ]
#          },
#          "EVER_SMOKED_CIGARETTES": {
#             "$id": "dbgap:phv00375339.v1",
#             "description": "Answer to \"Have you ever smoked cigarettes?\"",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "DAILY_NR_CIGARETTES": {
#             "$id": "dbgap:phv00375343.v1",
#             "description": "Answer to \"On average, during the years that you have smoked, how many cigarettes did you smoke daily?\"",
#             "type": "integer, encoded value",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "BRONCHODILATOR_PILLS": {
#             "$id": "dbgap:phv00375322.v1",
#             "description": "Bronchodilator pills, capsules, or liquids (current use according to health questionnaire)",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "WEIGHT_KG": {
#             "$id": "dbgap:phv00375337.v2",
#             "description": "Subject weight in kg",
#             "type": "decimal, encoded value",
#             "$unit": "kg",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "BRONCHODILATOR_PILLS_RELIEF": {
#             "$id": "dbgap:phv00375323.v1",
#             "description": "Relief from bronchodilator pills, capsules, or liquids",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "CROMOLYN_INHALERS": {
#             "$id": "dbgap:phv00375330.v1",
#             "description": "Cromolyn inhalers (current use according to health questionnaire)",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "MOTHER_SMOKED": {
#             "$id": "dbgap:phv00375346.v1",
#             "description": "Answer to \"Did your mother smoke when you were a baby?\"",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes light smoker"
#                },
#                {
#                   "const": "2",
#                   "title": "Yes heavy smoker"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "CROMOLYN_INHALERS_RELIEF": {
#             "$id": "dbgap:phv00375331.v1",
#             "description": "Relief from cromolyn inhalers",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "ALLERGIC_RHINITIS": {
#             "$id": "dbgap:phv00375321.v1",
#             "description": "Self-reported allergic rhinitis based on health questionnaire",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "FEV1_FVC": {
#             "$id": "dbgap:phv00375336.v1",
#             "description": "FEV1/FVC (pre-bronchodilator)",
#             "type": "decimal, encoded value",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "STEROID_INHALERS": {
#             "$id": "dbgap:phv00375328.v1",
#             "description": "Steroid inhalers (current use according to health questionnaire)",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "BRONCHODILATOR_NEBULIZER": {
#             "$id": "dbgap:phv00375332.v1",
#             "description": "Bronchodilator by nebulizer (current use according to health questionnaire)",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "BRONCHODILATOR_INHALERS_RELIEF": {
#             "$id": "dbgap:phv00375327.v1",
#             "description": "Relief from bronchodilator inhalers",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "EVER_SMOKED_CIGARS": {
#             "$id": "dbgap:phv00375344.v1",
#             "description": "Answer to \"Have you ever smoked cigars?\"",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes ever"
#                },
#                {
#                   "const": "2",
#                   "title": "Yes currently"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "AFFECTION_STATUS": {
#             "$id": "dbgap:phv00273213.v2",
#             "description": "Case control status of the subject for asthma",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "Uncertain"
#                },
#                {
#                   "const": "1",
#                   "title": "Control"
#                },
#                {
#                   "const": "2",
#                   "title": "Case"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "RAW_PHADIATOP_PAU_L": {
#             "$id": "dbgap:phv00375319.v1",
#             "description": "Phadiatop measurements in PAU/L",
#             "type": "decimal, encoded value",
#             "$unit": "PAU/l",
#             "oneOf": [
#                {
#                   "const": "<0.1",
#                   "title": "Less than 0.1 PAU/l"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "FVC_PREBD": {
#             "$id": "dbgap:phv00375335.v1",
#             "description": "FVC = Forced Vital Capacity (pre-bronchodilator)",
#             "type": "decimal, encoded value",
#             "$unit": "liters",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "FATHER_SMOKED": {
#             "$id": "dbgap:phv00375347.v1",
#             "description": "Answer to \"Did your father smoke when you were a baby?\"",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes light smoker"
#                },
#                {
#                   "const": "2",
#                   "title": "Yes heavy smoker"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          }
#       }
#    }
# }

# %%
query1 = '''SELECT AFFECTION_STATUS, FEV1_FVC, FVC_PREBD, RAW_PHADIATOP_PAU_L
FROM bigquery.dbgap_synth.TOPMed_WGS_BAGS_Subject_Phenotypes
where FVC_PREBD < 2.2
'''

res = cl.runQuery(query1, returnType='dataframe')
res
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
# ____Page6_______________
# ____Page7_______________
# ____Page8_______________
#   AFFECTION_STATUS FEV1_FVC  FVC_PREBD RAW_PHADIATOP_PAU_L
# 0                2     None   1.920412                  NA
# 1                2     None   2.165323                <0.1
# 2                0     None   2.152361                  NA
# 3                1     None   2.105422                  NA

# %% [markdown]
# ### Simulacrum dataset

# %%
cl.listTableInfo('bigquery.simulacrum.av_patient', verbose=True)
# Out:
# _Schema for tablebigquery.simulacrum.av_patient_
# {
#    "name": "bigquery.simulacrum.av_patient",
#    "description": "Patient table from Simulacrum data release, version 1.2.0-2017, 2021-01-19\n\nThis is a package of synthetic data based on cancer registration data from \nthe Cancer Outcomes and Services Dataset (COSD) and the Systemic Anti-Cancer \nTreatment (SACT) dataset collected by the National Cancer Registration and \nAnalysis Service (NCRAS).\n\nAny analysis performed on this synthetic data will not correspond exactly to \nanalysis performed on the real data. The synthetic data does not contain real \npatients but just mimics specific statistical properties of the real data. To \nminimise the potential for confusion with real data, organisational codes in \nthis extract have been obfuscated.\n\n\nFor more information on the Simulacrum and licensing details, please see\n  https://simulacrum.healthdatainsight.org.uk/",
#    "data_model": {
#       "description": "Patient table from Simulacrum data release, version 1.2.0-2017, 2021-01-19\n\nThis is a package of synthetic data based on cancer registration data from \nthe Cancer Outcomes and Services Dataset (COSD) and the Systemic Anti-Cancer \nTreatment (SACT) dataset collected by the National Cancer Registration and \nAnalysis Service (NCRAS).\n\nAny analysis performed on this synthetic data will not correspond exactly to \nanalysis performed on the real data. The synthetic data does not contain real \npatients but just mimics specific statistical properties of the real data. To \nminimise the potential for confusion with real data, organisational codes in \nthis extract have been obfuscated.\n\n\nFor more information on the Simulacrum and licensing details, please see\n  https://simulacrum.healthdatainsight.org.uk/",
#       "name": "simulacrum_release_v1.2.0.2017_patient",
#       "data_model": {
#          "$id": "",
#          "description": "simulacrum_release_v1.2.0.2017",
#          "$schema": "http://json-schema.org/draft-07/schema",
#          "properties": {
#             "PATIENTID": {
#                "description": "Pseudonymised patient ID Note: The format of this field in the Simulacrum is deliberately different from the format of pseudonymised patient id for real individuals. For real individuals PATIENTID, MERGED_PATIENT_ID and other linkage IDs are different and stored in different formats.",
#                "type": "integer"
#             },
#             "SEX": {
#                "description": "Sex",
#                "type": "integer",
#                "oneOf": [
#                   {
#                      "const": "0",
#                      "title": "X NOT KNOWN"
#                   },
#                   {
#                      "const": "1",
#                      "title": "MALE"
#                   },
#                   {
#                      "const": "2",
#                      "title": "FEMALE"
#                   },
#                   {
#                      "const": "4000",
#                      "title": "INDETERMINATE"
#                   },
#                   {
#                      "const": "9",
#                      "title": "NOT SPECIFIED"
#                   }
#                ]
#             },
#             "LINKNUMBER": {
#                "description": "Pseudonymised cross-dataset linkage ID Note: The format of this field in the Simulacrum is deliberately different from the format of the original linkage ID for real individuals. Data is identical to that in AV_PATIENT and the field is present for convenience. For real individuals PATIENTID, MERGED_PATIENT_ID and this ID are different and stored in different formats.",
#                "type": "integer"
#             },
#             "ETHNICITY": {
#                "description": "Ethnicity",
#                "type": "text",
#                "oneOf": [
#                   {
#                      "const": "0",
#                      "title": "WHITE"
#                   },
#                   {
#                      "const": "8",
#                      "title": "8 OTHER"
#                   },
#                   {
#                      "const": "A",
#                      "title": "WHITE BRITISH"
#                   },
#                   {
#                      "const": "B",
#                      "title": "WHITE IRISH"
#                   },
#                   {
#                      "const": "C",
#                      "title": "C ANY OTHER WHITE BACKGROUND"
#                   },
#                   {
#                      "const": "C2",
#                      "title": "Northern Irish"
#                   },
#                   {
#                      "const": "C3",
#                      "title": "Other white, white unspecified"
#                   },
#                   {
#                      "const": "CA",
#                      "title": "English"
#                   },
#                   {
#                      "const": "CB",
#                      "title": "Scottish"
#                   },
#                   {
#                      "const": "CC",
#                      "title": "Welsh"
#                   },
#                   {
#                      "const": "CD",
#                      "title": "Cornish"
#                   },
#                   {
#                      "const": "CE",
#                      "title": "Cypriot (part not stated)"
#                   },
#                   {
#                      "const": "CF",
#                      "title": "Greek"
#                   },
#                   {
#                      "const": "CG",
#                      "title": "Greek Cypriot"
#                   },
#                   {
#                      "const": "CH",
#                      "title": "Turkish"
#                   },
#                   {
#                      "const": "CJ",
#                      "title": "Turkish Cypriot"
#                   },
#                   {
#                      "const": "CK",
#                      "title": "Italian"
#                   },
#                   {
#                      "const": "CL",
#                      "title": "Irish Traveller"
#                   },
#                   {
#                      "const": "CM",
#                      "title": "Traveller"
#                   },
#                   {
#                      "const": "CN",
#                      "title": "Gypsy/Romany"
#                   },
#                   {
#                      "const": "CP",
#                      "title": "Polish"
#                   },
#                   {
#                      "const": "CQ",
#                      "title": "All republics which made up the former USSR"
#                   },
#                   {
#                      "const": "CR",
#                      "title": "Kosovan"
#                   },
#                   {
#                      "const": "CS",
#                      "title": "Albanian"
#                   },
#                   {
#                      "const": "CT",
#                      "title": "Bosnian"
#                   },
#                   {
#                      "const": "CU",
#                      "title": "Croatian"
#                   },
#                   {
#                      "const": "CV",
#                      "title": "Serbian"
#                   },
#                   {
#                      "const": "CW",
#                      "title": "Other republics which made up the former Yugoslavia"
#                   },
#                   {
#                      "const": "CX",
#                      "title": "Mixed white"
#                   },
#                   {
#                      "const": "CY",
#                      "title": "Other white European, European unspecified, European mixed"
#                   },
#                   {
#                      "const": "D",
#                      "title": "WHITE AND BLACK CARIBBEAN"
#                   },
#                   {
#                      "const": "E",
#                      "title": "MIXED WHITE AND BLACK AFRICAN"
#                   },
#                   {
#                      "const": "F",
#                      "title": "MIXED WHITE AND ASIAN"
#                   },
#                   {
#                      "const": "G",
#                      "title": "G ANY OTHER MIXED BACKGROUND"
#                   },
#                   {
#                      "const": "GA",
#                      "title": "Black and Asian"
#                   },
#                   {
#                      "const": "GB",
#                      "title": "Black and Chinese"
#                   },
#                   {
#                      "const": "GC",
#                      "title": "Black and White"
#                   },
#                   {
#                      "const": "GD",
#                      "title": "Chinese and White"
#                   },
#                   {
#                      "const": "GE",
#                      "title": "Asian and Chinese"
#                   },
#                   {
#                      "const": "GF",
#                      "title": "Other Mixed, Mixed Unspecified"
#                   },
#                   {
#                      "const": "H",
#                      "title": "ASIAN INDIAN"
#                   },
#                   {
#                      "const": "J",
#                      "title": "ASIAN PAKISTANI"
#                   },
#                   {
#                      "const": "K",
#                      "title": "ASIAN BANGLADESHI"
#                   },
#                   {
#                      "const": "L",
#                      "title": "L ANY OTHER ASIAN BACKGROUND"
#                   },
#                   {
#                      "const": "LA",
#                      "title": "Mixed Asian"
#                   },
#                   {
#                      "const": "LB",
#                      "title": "Punjabi"
#                   },
#                   {
#                      "const": "LC",
#                      "title": "Kashmiri"
#                   },
#                   {
#                      "const": "LD",
#                      "title": "East African Asian"
#                   },
#                   {
#                      "const": "LE",
#                      "title": "Sri Lanka"
#                   },
#                   {
#                      "const": "LF",
#                      "title": "Tamil"
#                   },
#                   {
#                      "const": "LG",
#                      "title": "Sinhalese"
#                   },
#                   {
#                      "const": "LH",
#                      "title": "British Asian"
#                   },
#                   {
#                      "const": "LJ",
#                      "title": "Caribbean Asian"
#                   },
#                   {
#                      "const": "LK",
#                      "title": "Other Asian, Asian unspecified"
#                   },
#                   {
#                      "const": "M",
#                      "title": "BLACK CARIBBEAN"
#                   },
#                   {
#                      "const": "N",
#                      "title": "BLACK AFRICAN"
#                   },
#                   {
#                      "const": "P",
#                      "title": "P ANY OTHER BLACK BACKGROUND"
#                   },
#                   {
#                      "const": "PA",
#                      "title": "Somali"
#                   },
#                   {
#                      "const": "PB",
#                      "title": "Mixed Black"
#                   },
#                   {
#                      "const": "PC",
#                      "title": "Nigerian"
#                   },
#                   {
#                      "const": "PD",
#                      "title": "Black British"
#                   },
#                   {
#                      "const": "PE",
#                      "title": "Other Black, Black unspecified"
#                   },
#                   {
#                      "const": "R",
#                      "title": "CHINESE"
#                   },
#                   {
#                      "const": "S",
#                      "title": "S ANY OTHER ETHNIC GROUP"
#                   },
#                   {
#                      "const": "SA",
#                      "title": "Vietnamese"
#                   },
#                   {
#                      "const": "SB",
#                      "title": "Japanese"
#                   },
#                   {
#                      "const": "SC",
#                      "title": "Filipino"
#                   },
#                   {
#                      "const": "SD",
#                      "title": "Malaysian"
#                   },
#                   {
#                      "const": "SE",
#                      "title": "Any Other Group"
#                   },
#                   {
#                      "const": "X",
#                      "title": "X NOT KNOWN"
#                   },
#                   {
#                      "const": "Z",
#                      "title": "NOT STATED"
#                   }
#                ]
#             },
#             "DEATHCAUSECODE_1A": {
#                "description": "As provided with death notification Note: Codes are in ICD-10 format, and may be a comma-separated list",
#                "type": "text"
#             },
#             "DEATHCAUSECODE_1B": {
#                "description": "As provided with death notification Note: Codes are in ICD-10 format, and may be a comma-separated list",
#                "type": "text"
#             },
#             "DEATHCAUSECODE_1C": {
#                "description": "As provided with death notification Note: Codes are in ICD-10 format, and may be a comma-separated list",
#                "type": "text"
#             },
#             "DEATHCAUSECODE_2": {
#                "description": "As provided with death notification Note: Codes are in ICD-10 format, and may be a comma-separated list",
#                "type": "text"
#             },
#             "DEATHCAUSECODE_UNDERLYING": {
#                "description": "As provided with death notification Note: Codes are in ICD-10 format, and may be a comma-separated list",
#                "type": "text"
#             },
#             "DEATHLOCATIONCODE": {
#                "description": "Code of the location (type) where the patient died, e.g. patients home, hospice etc.",
#                "type": "text",
#                "oneOf": [
#                   {
#                      "const": "1",
#                      "title": "HOSPITAL"
#                   },
#                   {
#                      "const": "2",
#                      "title": "PRIVATE HOME"
#                   },
#                   {
#                      "const": "3",
#                      "title": "HOSPICE NOS"
#                   },
#                   {
#                      "const": "4",
#                      "title": "NURSING HOME"
#                   },
#                   {
#                      "const": "4077",
#                      "title": "NHS HOSPICE / SPECIALIST PALLIATIVE CARE UNIT"
#                   },
#                   {
#                      "const": "4087",
#                      "title": "VOLUNTARY HOSPICE / SPECIALIST PALLIATIVE CARE UNIT"
#                   },
#                   {
#                      "const": "4097",
#                      "title": "CARE HOME"
#                   },
#                   {
#                      "const": "4107",
#                      "title": "PATIENTS OWN HOME"
#                   },
#                   {
#                      "const": "4117",
#                      "title": "OTHER PRIVATE RESIDENCE (E.G. RELATIVES HOME, CARERS HOME)"
#                   },
#                   {
#                      "const": "4127",
#                      "title": "CARE HOME WITH NURSING"
#                   },
#                   {
#                      "const": "4137",
#                      "title": "CARE HOME WITHOUT NURSING"
#                   },
#                   {
#                      "const": "5",
#                      "title": "OTHER"
#                   },
#                   {
#                      "const": "X",
#                      "title": "UNKNOWN"
#                   }
#                ]
#             },
#             "NEWVITALSTATUS": {
#                "description": "Vital status of the patient",
#                "type": "text",
#                "oneOf": [
#                   {
#                      "const": "A",
#                      "title": "Alive"
#                   },
#                   {
#                      "const": "D",
#                      "title": "Dead"
#                   },
#                   {
#                      "const": "X",
#                      "title": "Exit Posting"
#                   }
#                ]
#             },
#             "VITALSTATUSDATE": {
#                "description": "Date of vital status Note: If the patient has embarked or died, this is the corresponding date. If the patient is alive, this is the last date of follow-up.",
#                "type": "text"
#             }
#          }
#       }
#    }
# }

# %%
query1 = '''SELECT *
FROM bigquery.simulacrum.av_patient
where DEATHCAUSECODE_1A = 'R54'
'''

res = cl.runQuery(query1, returnType='dataframe')
res
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
# ____Page6_______________
# ____Page7_______________
# ____Page8_______________
# ____Page9_______________
#       patientid  sex  linknumber ethnicity deathcausecode_1a  \
# 0      10078592    2   810078592         A               R54
# 1      10143453    1   810143453         A               R54
# 2      10149196    1   810149196      None               R54
# 3      60011606    2   860011606         A               R54
# 4      60021681    1   860021681         A               R54
# ...         ...  ...         ...       ...               ...
# 7856  290024421    1  1090024421         A               R54
# 7857  300012197    1  1100012197         A               R54
# 7858  320008204    2  1120008204      None               R54
# 7859  320008900    2  1120008900         J               R54
# 7860  330000038    1  1130000038         A               R54
#
#      deathcausecode_1b deathcausecode_1c deathcausecode_2  \
# 0                 C182          I10,I489             I269
# 1
# 2                 C349                               F109
# 3
# 4
# ...                ...               ...              ...
# 7856                                                 I251
# 7857
# 7858              K918
# 7859
# 7860
#
#      deathcausecode_underlying deathlocationcode newvitalstatus  \
# 0                                           None              A
# 1                         I679              None              D
# 2                         C459              None              D
# 3                          C19              None              D
# 4                          C19              None              D
# ...                        ...               ...            ...
# 7856                      I259                 X              A
# 7857                      D432                 X              A
# 7858                       C64                 X              A
# 7859                       C66                 X              A
# 7860                      C880                 X              A
#
#      vitalstatusdate
# 0         2018-11-11
# 1         2015-11-23
# 2         2017-09-13
# 3         2016-08-13
# 4         2018-03-09
# ...              ...
# 7856      2019-02-11
# 7857      2019-02-11
# 7858      2019-02-11
# 7859      2019-02-11
# 7860      2019-02-11
#
# [7861 rows x 12 columns]

# %% [markdown]
# ### Another asthma dataset

# %%
cl.listTableInfo('bigquery.dbgap_synth.TOPMed_WGS_CARE_PACT_Subject_Phenotypes', verbose=True)
# Out:
# _Schema for tablebigquery.dbgap_synth.TOPMed_WGS_CARE_PACT_Subject_Phenotypes_
# {
#    "name": "bigquery.dbgap_synth.TOPMed_WGS_CARE_PACT_Subject_Phenotypes",
#    "data_model": {
#       "description": "This subject phenotypes data table includes subject's age, sex, race, BMI, affection status for asthma, smoking status, hospital admission for asthma, prescribed oral steroids for asthma use, and delta FEV1 measurements.",
#       "$id": "dbgap:pht010132.v1",
#       "properties": {
#          "SUBJECT_ID": {
#             "$id": "dbgap:phv00430283.v1",
#             "description": "De-identified Subject ID",
#             "type": "string"
#          },
#          "SEX": {
#             "$id": "dbgap:phv00430285.v1",
#             "description": "Gender of participant",
#             "type": "string"
#          },
#          "Race": {
#             "$id": "dbgap:phv00430286.v1",
#             "description": "Race of participant",
#             "type": "string"
#          },
#          "Affection_Status": {
#             "$id": "dbgap:phv00430288.v1",
#             "description": "Case or Control for asthma",
#             "type": "string"
#          },
#          "asthma_hospital_Yes12mo": {
#             "$id": "dbgap:phv00430290.v1",
#             "description": "In the last 12 months, has participant been hospitalized because of asthma?",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                }
#             ]
#          },
#          "age": {
#             "$id": "dbgap:phv00430284.v1",
#             "description": "Subject age",
#             "type": "decimal",
#             "$unit": "years"
#          },
#          "BMI": {
#             "$id": "dbgap:phv00430287.v1",
#             "description": "Body Mass Index calculated from Height and Weight",
#             "type": "decimal"
#          },
#          "smoke_current": {
#             "$id": "dbgap:phv00430289.v1",
#             "description": "Does participant currently smoke at least 1 cig per day?",
#             "type": "string"
#          },
#          "steroids_Yes12mo": {
#             "$id": "dbgap:phv00430291.v1",
#             "description": "In the last 12 months, has participant been prescribed oral steroids (such as prednisone pills or prelone liquid) to help control asthma?",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                }
#             ]
#          },
#          "delta1": {
#             "$id": "dbgap:phv00430292.v1",
#             "description": "Bronchodilator Response after 4 puffs of Proventil HFA Albuterol",
#             "type": "decimal"
#          }
#       }
#    }
# }

# %%
def findVariables(table, term):
    table_info = cl.listTableInfo(table)
    for var, prop in table_info.schema['data_model']['properties'].items():
        if term.lower() in var.lower():
            #print(var, prop['description'])

            print(var)

            
findVariables('bigquery.dbgap_synth.TOPMed_WGS_BAGS_Subject_Phenotypes', 'FEV')
# Out:
# FEV1_PREBD
# FEV1_FVC

# %%
asthma_phenotype_tables = ['bigquery.dbgap_synth.TOPMed_WGS_CAMP_Subject_Phenotypes',
'bigquery.dbgap_synth.TOPMed_WGS_CARE_PACT_Subject_Phenotypes',
'bigquery.dbgap_synth.TOPMed_WGS_BAGS_Subject_Phenotypes',
'bigquery.copdgene.subject_phenotypes_hmb',
'bigquery.esp_lunggo_copdgene.subject_phenotypes_hmb',
'bigquery.dbgap_synth.camp_cdata',
'bigquery.dbgap_synth.camp_ldata',
'bigquery.mesa.airnrspirometry_hmb',
'bigquery.topmed_wgs_partners_afgen.subject_phenotypes_hmb']

for t in asthma_phenotype_tables:
    print(t)
    findVariables(t,'fev')
    print('_'*80)
# Out:
# bigquery.dbgap_synth.TOPMed_WGS_CAMP_Subject_Phenotypes
# ________________________________________________________________________________
# bigquery.dbgap_synth.TOPMed_WGS_CARE_PACT_Subject_Phenotypes
# ________________________________________________________________________________
# bigquery.dbgap_synth.TOPMed_WGS_BAGS_Subject_Phenotypes
# FEV1_PREBD
# FEV1_FVC
# ________________________________________________________________________________
# bigquery.copdgene.subject_phenotypes_hmb
# hayfev
# hayfevage
# hayfevagedk
# hayfevdxbydr
# hayfevstillhave
# hayfevagestop
# hayfevstill
# hayfevtreat
# fev1pp_post
# fev1_fvc_post
# fev1_post
# fev6_post
# fev1_pre
# fev6_pre
# fev1_fvc_pre
# deltafev1
# bdr_pct_fev1
# ________________________________________________________________________________
# bigquery.esp_lunggo_copdgene.subject_phenotypes_hmb
# ________________________________________________________________________________
# bigquery.dbgap_synth.camp_cdata
# prefev_baseline
# prefevpp_baseline
# ________________________________________________________________________________
# bigquery.dbgap_synth.camp_ldata
# prefev
# prefevpp
# posfev
# posfevpp
# ________________________________________________________________________________
# bigquery.mesa.airnrspirometry_hmb
# fev1qaa4
# llfev1a4
# llfev6a4
# lfev1fa4
# lfev16a4
# bfev1a4
# fev1qna4
# fev1a4
# fev6a4
# fevfvca4
# qhfeva4
# pfev1a4
# pfev6a4
# ppfev1a4
# ppfev6a4
# ________________________________________________________________________________
# bigquery.topmed_wgs_partners_afgen.subject_phenotypes_hmb
# ________________________________________________________________________________

# %%
for t in asthma_phenotype_tables:
    print(t)
    cl.listTableColumns(t)
    print('_'*80)
# Out:
# bigquery.dbgap_synth.TOPMed_WGS_CAMP_Subject_Phenotypes
# gender
# _______________________________________
# race
# _______________________________________
# SUBJECT_ID
# _______________________________________
# weight
# _______________________________________
# asthma
# _______________________________________
# current_smoker
# _______________________________________
# age
# _______________________________________
# former_smoker
# _______________________________________
# height
# _______________________________________
# bmi
# _______________________________________
# ever_smoker
# _______________________________________
# ________________________________________________________________________________
# bigquery.dbgap_synth.TOPMed_WGS_CARE_PACT_Subject_Phenotypes
# SUBJECT_ID
# _______________________________________
# SEX
# _______________________________________
# Race
# _______________________________________
# Affection_Status
# _______________________________________
# asthma_hospital_Yes12mo
# _______________________________________
# age
# _______________________________________
# BMI
# _______________________________________
# smoke_current
# _______________________________________
# steroids_Yes12mo
# _______________________________________
# delta1
# _______________________________________
# ________________________________________________________________________________
# bigquery.dbgap_synth.TOPMed_WGS_BAGS_Subject_Phenotypes
# AGE_START_SMOKING
# _______________________________________
# STEROID_PILLS
# _______________________________________
# SEX
# _______________________________________
# BRONCHODILATOR_INHALERS
# _______________________________________
# FEV1_PREBD
# _______________________________________
# EVER_SMOKED_PIPE
# _______________________________________
# STEROID_INHALERS_RELIEF
# _______________________________________
# LOG10_IGE_NG_ML
# _______________________________________
# BRONCHODILATOR_NEBULIZER_RELIEF
# _______________________________________
# AGE_IGE
# _______________________________________
# AGE_ONSET_ASTHMA
# _______________________________________
# SUBJECT_ID
# _______________________________________
# STEROID_PILLS_RELIEF
# _______________________________________
# CURRENT_SMOKING
# _______________________________________
# AGE_STOPPED_SMOKING
# _______________________________________
# AGE
# _______________________________________
# HEIGHT_CM
# _______________________________________
# IGE_BATCH
# _______________________________________
# EVER_SMOKED_CIGARETTES
# _______________________________________
# DAILY_NR_CIGARETTES
# _______________________________________
# BRONCHODILATOR_PILLS
# _______________________________________
# WEIGHT_KG
# _______________________________________
# BRONCHODILATOR_PILLS_RELIEF
# _______________________________________
# CROMOLYN_INHALERS
# _______________________________________
# MOTHER_SMOKED
# _______________________________________
# CROMOLYN_INHALERS_RELIEF
# _______________________________________
# ALLERGIC_RHINITIS
# _______________________________________
# FEV1_FVC
# _______________________________________
# STEROID_INHALERS
# _______________________________________
# BRONCHODILATOR_NEBULIZER
# _______________________________________
# BRONCHODILATOR_INHALERS_RELIEF
# _______________________________________
# EVER_SMOKED_CIGARS
# _______________________________________
# AFFECTION_STATUS
# _______________________________________
# RAW_PHADIATOP_PAU_L
# _______________________________________
# FVC_PREBD
# _______________________________________
# FATHER_SMOKED
# _______________________________________
# ________________________________________________________________________________

# %%
cl.listTableInfo('bigquery.dbgap_synth.TOPMed_WGS_BAGS_Subject_Phenotypes', verbose=True)
# Out:
# _Schema for tablebigquery.dbgap_synth.TOPMed_WGS_BAGS_Subject_Phenotypes_
# {
#    "name": "bigquery.dbgap_synth.TOPMed_WGS_BAGS_Subject_Phenotypes",
#    "description": "This subject phenotype table includes age, sex, and affection status for asthma. Additional variables have been added: smoking status (n=9 variables; includes mother and father smoking status), asthma age of onset, allergic rhinitis, weight, height, IgE measurements (n=3 variables), phadiatop measurements, spirometry measurements (n=3 variables), bronchodilator pills/inhalers/nebulizer (n=6 variables), steroid pills/inhalers (n=4 variables), and cromolyn inhalers (n=2 variables).",
#    "data_model": {
#       "$id": "dbgap:pht005905.v3",
#       "description": "This subject phenotype table includes age, sex, and affection status for asthma. Additional variables have been added: smoking status (n=9 variables; includes mother and father smoking status), asthma age of onset, allergic rhinitis, weight, height, IgE measurements (n=3 variables), phadiatop measurements, spirometry measurements (n=3 variables), bronchodilator pills/inhalers/nebulizer (n=6 variables), steroid pills/inhalers (n=4 variables), and cromolyn inhalers (n=2 variables).",
#       "properties": {
#          "AGE_START_SMOKING": {
#             "type": "integer, encoded value",
#             "$id": "dbgap:phv00375340.v1",
#             "description": "Answer to \"At what age did you start smoking?\"",
#             "$unit": "years",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "STEROID_PILLS": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375324.v1",
#             "description": "Steroid/prednisone pills (current use according to health questionnaire)",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "SEX": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00273212.v2",
#             "description": "Sex of participant",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "Male"
#                },
#                {
#                   "const": "2",
#                   "title": "Female"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "BRONCHODILATOR_INHALERS": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375326.v1",
#             "description": "Bronchodilator inhalers (current use according to health questionnaire)",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "FEV1_PREBD": {
#             "type": "decimal, encoded value",
#             "$id": "dbgap:phv00375334.v1",
#             "description": "FEV1 = Forced Expiratory Volume 1 (pre-bronchodilator)",
#             "$unit": "liters/second",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "EVER_SMOKED_PIPE": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375345.v1",
#             "description": "Answer to \"Have you ever smoked a pipe?\"",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes ever"
#                },
#                {
#                   "const": "2",
#                   "title": "Yes currently"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "STEROID_INHALERS_RELIEF": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375329.v1",
#             "description": "Relief from steroid inhalers",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "LOG10_IGE_NG_ML": {
#             "type": "decimal, encoded value",
#             "$id": "dbgap:phv00375316.v2",
#             "description": "Log10 (Total serum IgE in ng/ml)",
#             "$unit": "ng/ml",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "BRONCHODILATOR_NEBULIZER_RELIEF": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375333.v1",
#             "description": "Relief from bronchodilator by nebulizer",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "AGE_IGE": {
#             "type": "integer, encoded value",
#             "$id": "dbgap:phv00375318.v1",
#             "description": "Age of subject when sample used for total serum IgE measurement was collected",
#             "$unit": "years",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "AGE_ONSET_ASTHMA": {
#             "type": "integer, encoded value",
#             "$id": "dbgap:phv00375320.v1",
#             "description": "Age of asthma onset",
#             "$unit": "years",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "SUBJECT_ID": {
#             "type": "string",
#             "$id": "dbgap:phv00273210.v2",
#             "description": "De-identified Subject ID"
#          },
#          "STEROID_PILLS_RELIEF": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375325.v1",
#             "description": "Relief from steroid/prednisone pills",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "CURRENT_SMOKING": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375341.v1",
#             "description": "Answer to \"Are you smoking now?\"",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "AGE_STOPPED_SMOKING": {
#             "type": "integer, encoded value",
#             "$id": "dbgap:phv00375342.v1",
#             "description": "Answer to \"At what age did you stop smoking?\"",
#             "$unit": "years",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "AGE": {
#             "type": "integer, encoded value",
#             "$id": "dbgap:phv00273211.v2",
#             "description": "Subject age at health questionnaire administration and lung function measurement",
#             "$unit": "years",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "HEIGHT_CM": {
#             "type": "decimal, encoded value",
#             "$id": "dbgap:phv00375338.v2",
#             "description": "Subject height in cm",
#             "$unit": "cm",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "IGE_BATCH": {
#             "type": "string, encoded value",
#             "$id": "dbgap:phv00375317.v1",
#             "description": "Batch in which total serum IgE and phadiatop measurements were run",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                },
#                {
#                   "title": "STRINGS"
#                }
#             ]
#          },
#          "EVER_SMOKED_CIGARETTES": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375339.v1",
#             "description": "Answer to \"Have you ever smoked cigarettes?\"",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "DAILY_NR_CIGARETTES": {
#             "type": "integer, encoded value",
#             "$id": "dbgap:phv00375343.v1",
#             "description": "Answer to \"On average, during the years that you have smoked, how many cigarettes did you smoke daily?\"",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "BRONCHODILATOR_PILLS": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375322.v1",
#             "description": "Bronchodilator pills, capsules, or liquids (current use according to health questionnaire)",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "WEIGHT_KG": {
#             "type": "decimal, encoded value",
#             "$id": "dbgap:phv00375337.v2",
#             "description": "Subject weight in kg",
#             "$unit": "kg",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "BRONCHODILATOR_PILLS_RELIEF": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375323.v1",
#             "description": "Relief from bronchodilator pills, capsules, or liquids",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "CROMOLYN_INHALERS": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375330.v1",
#             "description": "Cromolyn inhalers (current use according to health questionnaire)",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "MOTHER_SMOKED": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375346.v1",
#             "description": "Answer to \"Did your mother smoke when you were a baby?\"",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes light smoker"
#                },
#                {
#                   "const": "2",
#                   "title": "Yes heavy smoker"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "CROMOLYN_INHALERS_RELIEF": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375331.v1",
#             "description": "Relief from cromolyn inhalers",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "ALLERGIC_RHINITIS": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375321.v1",
#             "description": "Self-reported allergic rhinitis based on health questionnaire",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "FEV1_FVC": {
#             "type": "decimal, encoded value",
#             "$id": "dbgap:phv00375336.v1",
#             "description": "FEV1/FVC (pre-bronchodilator)",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "STEROID_INHALERS": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375328.v1",
#             "description": "Steroid inhalers (current use according to health questionnaire)",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "BRONCHODILATOR_NEBULIZER": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375332.v1",
#             "description": "Bronchodilator by nebulizer (current use according to health questionnaire)",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "BRONCHODILATOR_INHALERS_RELIEF": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375327.v1",
#             "description": "Relief from bronchodilator inhalers",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "EVER_SMOKED_CIGARS": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375344.v1",
#             "description": "Answer to \"Have you ever smoked cigars?\"",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes ever"
#                },
#                {
#                   "const": "2",
#                   "title": "Yes currently"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "AFFECTION_STATUS": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00273213.v2",
#             "description": "Case control status of the subject for asthma",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "Uncertain"
#                },
#                {
#                   "const": "1",
#                   "title": "Control"
#                },
#                {
#                   "const": "2",
#                   "title": "Case"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "RAW_PHADIATOP_PAU_L": {
#             "type": "decimal, encoded value",
#             "$id": "dbgap:phv00375319.v1",
#             "description": "Phadiatop measurements in PAU/L",
#             "$unit": "PAU/l",
#             "oneOf": [
#                {
#                   "const": "<0.1",
#                   "title": "Less than 0.1 PAU/l"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "FVC_PREBD": {
#             "type": "decimal, encoded value",
#             "$id": "dbgap:phv00375335.v1",
#             "description": "FVC = Forced Vital Capacity (pre-bronchodilator)",
#             "$unit": "liters",
#             "oneOf": [
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          },
#          "FATHER_SMOKED": {
#             "type": "encoded value",
#             "$id": "dbgap:phv00375347.v1",
#             "description": "Answer to \"Did your father smoke when you were a baby?\"",
#             "oneOf": [
#                {
#                   "const": "0",
#                   "title": "No"
#                },
#                {
#                   "const": "1",
#                   "title": "Yes light smoker"
#                },
#                {
#                   "const": "2",
#                   "title": "Yes heavy smoker"
#                },
#                {
#                   "const": "NA",
#                   "title": "Missing"
#                }
#             ]
#          }
#       }
#    }
# }

# %%
cl.listCatalog('bigquery')
# Out:
# Retrieving the table list
# ____Page1_______________
# bigquery.1000genomes.1000genomes_drs
# bigquery.1000genomes.aligned_read
# bigquery.1000genomes.aliquot
# bigquery.1000genomes.bdc_1000genomes
# bigquery.1000genomes.demographics
# bigquery.1000genomes.germline_variation_index
# bigquery.1000genomes.phenotype_drs
# bigquery.1000genomes.read_group
# bigquery.1000genomes.sample
# bigquery.1000genomes.simple_germline_variation
# bigquery.1000genomes.ssd_drs
# bigquery.1000genomes.ssd_drs_table
# bigquery.1000genomes.subject
# bigquery.100genomes.import2
# bigquery.100genomes.import3
# bigquery.100genomes.testimport
# bigquery.blog_unnest.firebase_raw
# bigquery.cda.cdav3
# bigquery.cidr_gecco_colorectal_cancer_gxe.sample
# bigquery.cidr_gecco_colorectal_cancer_gxe.sample_attributes
# bigquery.cidr_gecco_colorectal_cancer_gxe.subject
# bigquery.cidr_gecco_colorectal_cancer_gxe.subject_phenotypes
# bigquery.cidr_ndd_g2.pedigree
# bigquery.cidr_ndd_g2.sample_attributes
# bigquery.cidr_ndd_g2.subject_phenotypes
# bigquery.cineca.syn_africa_h3abionet_v1
# bigquery.cineca.syn_europe_ch_sib
# bigquery.connect22.h3abionet
# bigquery.copdgene.aligned_read
# bigquery.copdgene.aliquot
# bigquery.copdgene.copd_drs
# bigquery.copdgene.copd_gene__hmb_vcf
# bigquery.copdgene.copdgene_hmb_female_90_94kg
# bigquery.copdgene.copdgene_pfb
# bigquery.copdgene.phenotype_drs
# bigquery.copdgene.read_group
# bigquery.copdgene.sample
# bigquery.copdgene.sample_multi
# bigquery.copdgene.subject
# bigquery.copdgene.subject_images_hmb
# bigquery.copdgene.subject_multi
# bigquery.copdgene.subject_phenotypes_hmb
# bigquery.cptac.breastsubjectclinicalphenotypes
# bigquery.cptac.sample_attributes
# bigquery.dbgap_synth.camp_cdata
# bigquery.dbgap_synth.camp_ldata
# bigquery.dbgap_synth.gecco_crc_susceptibility_subject_phenotypes
# bigquery.dbgap_synth.topmed_wgs_bags_subject_phenotypes
# bigquery.dbgap_synth.topmed_wgs_camp_subject_phenotypes
# bigquery.esp_lunggo_copdgene.sample_attributes_hmb
# bigquery.esp_lunggo_copdgene.subject_phenotypes_hmb
# bigquery.ewingsarcoma.pedigree
# bigquery.ewingsarcoma.sample
# bigquery.ewingsarcoma.subject
# bigquery.fasp_scrambled.scr_egapancreatic_sample
# bigquery.gecco_crc_susceptibility.public_sample
# bigquery.gecco_crc_susceptibility.sample_attributes
# bigquery.gecco_crc_susceptibility.sample_attributes_cadm
# bigquery.gecco_crc_susceptibility.sample_attributes_ds_cc_npu_gso
# bigquery.gecco_crc_susceptibility.sample_attributes_gru
# bigquery.gecco_crc_susceptibility.sample_attributes_hmb_irb
# bigquery.gecco_crc_susceptibility.sample_attributes_hmb_irb_npu
# bigquery.gecco_crc_susceptibility.sample_multi
# bigquery.gecco_crc_susceptibility.studies_1554
# bigquery.gecco_crc_susceptibility.subject_multi
# bigquery.gecco_crc_susceptibility.subject_phenotypes
# bigquery.gecco_crc_susceptibility.subject_phenotypes_cadm
# bigquery.gecco_crc_susceptibility.subject_phenotypes_ds_cc_npu_gso
# bigquery.gecco_crc_susceptibility.subject_phenotypes_gru
# bigquery.gecco_crc_susceptibility.subject_phenotypes_hmb_irb
# bigquery.gecco_crc_susceptibility.subject_phenotypes_hmb_irb_npu
# bigquery.gtex8.program
# bigquery.gtex8.project
# bigquery.gtex8.sample
# bigquery.gtex8.sequencing
# bigquery.gtex8.sraruntable_breast_cram
# bigquery.gtex8.sraruntable_nocram
# bigquery.gtex8.sraruntable_nocram_nobam
# bigquery.gtex8.subject
# bigquery.icdc.cotc_sample
# bigquery.kidsfirst.neuroblastoma_participant_family
# bigquery.kidsfirst.pediatric_brain_tumor_atlas
# bigquery.lccc_1108.lccc_drs_map
# bigquery.lccc_1108.sample
# bigquery.lccc_1108.sample_attributes
# bigquery.lccc_1108.subject
# bigquery.lccc_1108.subject_phenotypes
# bigquery.mapped.age_months_view
# bigquery.mapped.age_months_view2
# bigquery.mapped.age_view
# bigquery.mapped.age_years
# bigquery.mapped.subject_disease
# bigquery.mesa.airnrexammain_hmb
# bigquery.mesa.airnrspirometry_hmb
# bigquery.mesa.ancilmesaneighborfoodexam1_hmb
# bigquery.mesa.ancilmesaneighborfoodexam2_hmb
# bigquery.mesa.ancilmesaneighborfoodexam3_hmb
# bigquery.mesa.ancilmesaneighborfoodexam4_hmb
# bigquery.mesa.parent_mesa_hmb_npu
# bigquery.mesa.sample_multi
# bigquery.mesa.subject_multi
# bigquery.mesa_esp_heartgo.parent_mesa
# bigquery.mesa_esp_heartgo.sample_attributes_hmb
# bigquery.mesa_esp_heartgo.sample_attributes_hmb_npu
# bigquery.mesa_esp_heartgo.subject_phenotypes_hmb
# bigquery.mesa_esp_heartgo.subject_phenotypes_hmb_npu
# bigquery.metadata.dbgap_table
# bigquery.metadata.loinc2hpoannotation
# bigquery.metadata.mapping
# bigquery.metadata.mapping2
# bigquery.metadata.mapping2_term
# bigquery.metadata.merged
# bigquery.metadata.s_study
# bigquery.metadata.s_table
# bigquery.metadata.s_variable
# bigquery.metadata.study
# bigquery.metadata.value_map
# bigquery.metadata.vocab
# bigquery.metadata.vocab_term
# bigquery.onek_genomes.bdc_1000genomes
# bigquery.onek_genomes.onek_drs
# bigquery.onek_genomes.onek_recal_variants_drs
# bigquery.onek_genomes.sra_drs_files
# bigquery.onek_genomes.sra_onek_drs
# bigquery.onek_genomes.ssd_drs
# bigquery.onek_genomes.thousand_genomes_meta
# bigquery.organoid_profiling_pc.sample_attributes_gru
# bigquery.organoid_profiling_pc.sample_multi
# bigquery.organoid_profiling_pc.subject_multi
# bigquery.organoid_profiling_pc.subject_phenotypes_gru
# bigquery.pc_rare_variation.sample
# bigquery.pc_rare_variation.sample_attributes
# bigquery.pc_rare_variation.subject
# bigquery.pc_rare_variation.subject_phenotypes
# bigquery.plggs.plggs_sample_attributes
# bigquery.pptc.manifest_small
# bigquery.pptc.sample
# bigquery.pptc.sample_attributes
# bigquery.pptc.subject
# bigquery.pptc.subject_phenotypes
# bigquery.rand_gmkf_cdh.phenotype
# bigquery.scr_ega.scr_egapancreatic_files
# bigquery.scr_ega.scr_egapancreatic_sample_multi
# bigquery.scr_egapancreatic.sample
# bigquery.scr_gecco_susceptibility.gecco_sample_acc
# bigquery.scr_gecco_susceptibility.phs001554_gecco_sddp_manifest
# bigquery.scr_gecco_susceptibility.sample_attributes_multi
# bigquery.scr_gecco_susceptibility.sample_multi
# bigquery.scr_gecco_susceptibility.sb_drs_index
# bigquery.scr_gecco_susceptibility.subject_multi
# bigquery.scr_gecco_susceptibility.subject_phenotypes_multi
# bigquery.scr_organoid.subject_phenotypes_gru
# bigquery.scripts.pipelinelog
# bigquery.scripts.scriptlist
# bigquery.simulacrum.av_patient
# bigquery.simulacrum.sact_patient
# bigquery.sra.accession_summary
# bigquery.sra.gecco_join
# bigquery.sra.run
# bigquery.sra.run_file
# bigquery.synthea.patient
# bigquery.tgtest.program
# bigquery.tgtest.project
# bigquery.tgtest.sample
# bigquery.tgtest.sequencing
# bigquery.tgtest.subject
# bigquery.topmed_wgs_mayo_vte.sample_attributes_gru
# bigquery.topmed_wgs_mayo_vte.subject_multi
# bigquery.topmed_wgs_mayo_vte.subject_phenotypes_gru
# bigquery.topmed_wgs_partners_afgen.sample_attributes_hmb
# bigquery.topmed_wgs_partners_afgen.sample_multi
# bigquery.topmed_wgs_partners_afgen.subject_multi
# bigquery.topmed_wgs_partners_afgen.subject_phenotypes_hmb
# bigquery.transfer.gdc_case_file_metadata_gdcfileid_to_gcsurl_current
# bigquery.transfer.tcga_clinical_gdc_current
# bigquery.transfer.tcga_somatic_mutation_hg38_gdc_current
# ['bigquery.1000genomes.1000genomes_drs',
#  'bigquery.1000genomes.aligned_read',
#  'bigquery.1000genomes.aliquot',
#  'bigquery.1000genomes.bdc_1000genomes',
#  'bigquery.1000genomes.demographics',
#  'bigquery.1000genomes.germline_variation_index',
#  'bigquery.1000genomes.phenotype_drs',
#  'bigquery.1000genomes.read_group',
#  'bigquery.1000genomes.sample',
#  'bigquery.1000genomes.simple_germline_variation',
#  'bigquery.1000genomes.ssd_drs',
#  'bigquery.1000genomes.ssd_drs_table',
#  'bigquery.1000genomes.subject',
#  'bigquery.100genomes.import2',
#  'bigquery.100genomes.import3',
#  'bigquery.100genomes.testimport',
#  'bigquery.blog_unnest.firebase_raw',
#  'bigquery.cda.cdav3',
#  'bigquery.cidr_gecco_colorectal_cancer_gxe.sample',
#  'bigquery.cidr_gecco_colorectal_cancer_gxe.sample_attributes',
#  'bigquery.cidr_gecco_colorectal_cancer_gxe.subject',
#  'bigquery.cidr_gecco_colorectal_cancer_gxe.subject_phenotypes',
#  'bigquery.cidr_ndd_g2.pedigree',
#  'bigquery.cidr_ndd_g2.sample_attributes',
#  'bigquery.cidr_ndd_g2.subject_phenotypes',
#  'bigquery.cineca.syn_africa_h3abionet_v1',
#  'bigquery.cineca.syn_europe_ch_sib',
#  'bigquery.connect22.h3abionet',
#  'bigquery.copdgene.aligned_read',
#  'bigquery.copdgene.aliquot',
#  'bigquery.copdgene.copd_drs',
#  'bigquery.copdgene.copd_gene__hmb_vcf',
#  'bigquery.copdgene.copdgene_hmb_female_90_94kg',
#  'bigquery.copdgene.copdgene_pfb',
#  'bigquery.copdgene.phenotype_drs',
#  'bigquery.copdgene.read_group',
#  'bigquery.copdgene.sample',
#  'bigquery.copdgene.sample_multi',
#  'bigquery.copdgene.subject',
#  'bigquery.copdgene.subject_images_hmb',
#  'bigquery.copdgene.subject_multi',
#  'bigquery.copdgene.subject_phenotypes_hmb',
#  'bigquery.cptac.breastsubjectclinicalphenotypes',
#  'bigquery.cptac.sample_attributes',
#  'bigquery.dbgap_synth.camp_cdata',
#  'bigquery.dbgap_synth.camp_ldata',
#  'bigquery.dbgap_synth.gecco_crc_susceptibility_subject_phenotypes',
#  'bigquery.dbgap_synth.topmed_wgs_bags_subject_phenotypes',
#  'bigquery.dbgap_synth.topmed_wgs_camp_subject_phenotypes',
#  'bigquery.esp_lunggo_copdgene.sample_attributes_hmb',
#  'bigquery.esp_lunggo_copdgene.subject_phenotypes_hmb',
#  'bigquery.ewingsarcoma.pedigree',
#  'bigquery.ewingsarcoma.sample',
#  'bigquery.ewingsarcoma.subject',
#  'bigquery.fasp_scrambled.scr_egapancreatic_sample',
#  'bigquery.gecco_crc_susceptibility.public_sample',
#  'bigquery.gecco_crc_susceptibility.sample_attributes',
#  'bigquery.gecco_crc_susceptibility.sample_attributes_cadm',
#  'bigquery.gecco_crc_susceptibility.sample_attributes_ds_cc_npu_gso',
#  'bigquery.gecco_crc_susceptibility.sample_attributes_gru',
#  'bigquery.gecco_crc_susceptibility.sample_attributes_hmb_irb',
#  'bigquery.gecco_crc_susceptibility.sample_attributes_hmb_irb_npu',
#  'bigquery.gecco_crc_susceptibility.sample_multi',
#  'bigquery.gecco_crc_susceptibility.studies_1554',
#  'bigquery.gecco_crc_susceptibility.subject_multi',
#  'bigquery.gecco_crc_susceptibility.subject_phenotypes',
#  'bigquery.gecco_crc_susceptibility.subject_phenotypes_cadm',
#  'bigquery.gecco_crc_susceptibility.subject_phenotypes_ds_cc_npu_gso',
#  'bigquery.gecco_crc_susceptibility.subject_phenotypes_gru',
#  'bigquery.gecco_crc_susceptibility.subject_phenotypes_hmb_irb',
#  'bigquery.gecco_crc_susceptibility.subject_phenotypes_hmb_irb_npu',
#  'bigquery.gtex8.program',
#  'bigquery.gtex8.project',
#  'bigquery.gtex8.sample',
#  'bigquery.gtex8.sequencing',
#  'bigquery.gtex8.sraruntable_breast_cram',
#  'bigquery.gtex8.sraruntable_nocram',
#  'bigquery.gtex8.sraruntable_nocram_nobam',
#  'bigquery.gtex8.subject',
#  'bigquery.icdc.cotc_sample',
#  'bigquery.kidsfirst.neuroblastoma_participant_family',
#  'bigquery.kidsfirst.pediatric_brain_tumor_atlas',
#  'bigquery.lccc_1108.lccc_drs_map',
#  'bigquery.lccc_1108.sample',
#  'bigquery.lccc_1108.sample_attributes',
#  'bigquery.lccc_1108.subject',
#  'bigquery.lccc_1108.subject_phenotypes',
#  'bigquery.mapped.age_months_view',
#  'bigquery.mapped.age_months_view2',
#  'bigquery.mapped.age_view',
#  'bigquery.mapped.age_years',
#  'bigquery.mapped.subject_disease',
#  'bigquery.mesa.airnrexammain_hmb',
#  'bigquery.mesa.airnrspirometry_hmb',
#  'bigquery.mesa.ancilmesaneighborfoodexam1_hmb',
#  'bigquery.mesa.ancilmesaneighborfoodexam2_hmb',
#  'bigquery.mesa.ancilmesaneighborfoodexam3_hmb',
#  'bigquery.mesa.ancilmesaneighborfoodexam4_hmb',
#  'bigquery.mesa.parent_mesa_hmb_npu',
#  'bigquery.mesa.sample_multi',
#  'bigquery.mesa.subject_multi',
#  'bigquery.mesa_esp_heartgo.parent_mesa',
#  'bigquery.mesa_esp_heartgo.sample_attributes_hmb',
#  'bigquery.mesa_esp_heartgo.sample_attributes_hmb_npu',
#  'bigquery.mesa_esp_heartgo.subject_phenotypes_hmb',
#  'bigquery.mesa_esp_heartgo.subject_phenotypes_hmb_npu',
#  'bigquery.metadata.dbgap_table',
#  'bigquery.metadata.loinc2hpoannotation',
#  'bigquery.metadata.mapping',
#  'bigquery.metadata.mapping2',
#  'bigquery.metadata.mapping2_term',
#  'bigquery.metadata.merged',
#  'bigquery.metadata.s_study',
#  'bigquery.metadata.s_table',
#  'bigquery.metadata.s_variable',
#  'bigquery.metadata.study',
#  'bigquery.metadata.value_map',
#  'bigquery.metadata.vocab',
#  'bigquery.metadata.vocab_term',
#  'bigquery.onek_genomes.bdc_1000genomes',
#  'bigquery.onek_genomes.onek_drs',
#  'bigquery.onek_genomes.onek_recal_variants_drs',
#  'bigquery.onek_genomes.sra_drs_files',
#  'bigquery.onek_genomes.sra_onek_drs',
#  'bigquery.onek_genomes.ssd_drs',
#  'bigquery.onek_genomes.thousand_genomes_meta',
#  'bigquery.organoid_profiling_pc.sample_attributes_gru',
#  'bigquery.organoid_profiling_pc.sample_multi',
#  'bigquery.organoid_profiling_pc.subject_multi',
#  'bigquery.organoid_profiling_pc.subject_phenotypes_gru',
#  'bigquery.pc_rare_variation.sample',
#  'bigquery.pc_rare_variation.sample_attributes',
#  'bigquery.pc_rare_variation.subject',
#  'bigquery.pc_rare_variation.subject_phenotypes',
#  'bigquery.plggs.plggs_sample_attributes',
#  'bigquery.pptc.manifest_small',
#  'bigquery.pptc.sample',
#  'bigquery.pptc.sample_attributes',
#  'bigquery.pptc.subject',
#  'bigquery.pptc.subject_phenotypes',
#  'bigquery.rand_gmkf_cdh.phenotype',
#  'bigquery.scr_ega.scr_egapancreatic_files',
#  'bigquery.scr_ega.scr_egapancreatic_sample_multi',
#  'bigquery.scr_egapancreatic.sample',
#  'bigquery.scr_gecco_susceptibility.gecco_sample_acc',
#  'bigquery.scr_gecco_susceptibility.phs001554_gecco_sddp_manifest',
#  'bigquery.scr_gecco_susceptibility.sample_attributes_multi',
#  'bigquery.scr_gecco_susceptibility.sample_multi',
#  'bigquery.scr_gecco_susceptibility.sb_drs_index',
#  'bigquery.scr_gecco_susceptibility.subject_multi',
#  'bigquery.scr_gecco_susceptibility.subject_phenotypes_multi',
#  'bigquery.scr_organoid.subject_phenotypes_gru',
#  'bigquery.scripts.pipelinelog',
#  'bigquery.scripts.scriptlist',
#  'bigquery.simulacrum.av_patient',
#  'bigquery.simulacrum.sact_patient',
#  'bigquery.sra.accession_summary',
#  'bigquery.sra.gecco_join',
#  'bigquery.sra.run',
#  'bigquery.sra.run_file',
#  'bigquery.synthea.patient',
#  'bigquery.tgtest.program',
#  'bigquery.tgtest.project',
#  'bigquery.tgtest.sample',
#  'bigquery.tgtest.sequencing',
#  'bigquery.tgtest.subject',
#  'bigquery.topmed_wgs_mayo_vte.sample_attributes_gru',
#  'bigquery.topmed_wgs_mayo_vte.subject_multi',
#  'bigquery.topmed_wgs_mayo_vte.subject_phenotypes_gru',
#  'bigquery.topmed_wgs_partners_afgen.sample_attributes_hmb',
#  'bigquery.topmed_wgs_partners_afgen.sample_multi',
#  'bigquery.topmed_wgs_partners_afgen.subject_multi',
#  'bigquery.topmed_wgs_partners_afgen.subject_phenotypes_hmb',
#  'bigquery.transfer.gdc_case_file_metadata_gdcfileid_to_gcsurl_current',
#  'bigquery.transfer.tcga_clinical_gdc_current',
#  'bigquery.transfer.tcga_somatic_mutation_hg38_gdc_current']
